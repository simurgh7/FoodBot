# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('./food_classification/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#   banh chung       1.00      1.00      1.00         3
#    banh cuon       1.00      1.00      1.00         2
#     banh pia       1.00      1.00      1.00         2
#    chao long       1.00      1.00      1.00         3
#          pho       1.00      1.00      1.00         2
#        pilaf       1.00      1.00      1.00         2
#       samosa       1.00      1.00      1.00         2
#     shawarma       1.00      1.00      1.00         2
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('./qa_category/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         C500       0.01      0.86      0.02         7
#         C501       0.14      0.75      0.23       103
#         C502       0.24      0.64      0.35       552
#         C503       0.29      0.17      0.21       304
#         C504       0.81      0.09      0.17      1898
#         C505       0.18      0.04      0.06       423
#
#     accuracy                           0.21      3287
#    macro avg       0.28      0.42      0.17      3287
# weighted avg       0.56      0.21      0.19      3287

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../gra_group_name_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#                                   precision    recall  f1-score   support
#
#                               G1       0.65      0.65      0.65       313
#                               G2       0.72      0.76      0.74       952
#                               G3       0.75      0.75      0.75       675
#                               G4       0.20      0.12      0.15         8
# NOT DETERMINED OR NOT APPLICABLE       0.53      0.38      0.44       220
#
#                         accuracy                           0.70      2168
#                        macro avg       0.57      0.53      0.55      2168
#                     weighted avg       0.70      0.70      0.70      2168

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../sta_group_name_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#              0       0.80      0.80      0.80       340
#              1       0.62      0.57      0.60        40
#             1A       0.80      0.87      0.84       795
#             1B       0.54      0.34      0.42       124
#             2A       0.66      0.70      0.68       227
#             2B       0.70      0.69      0.70        95
#             3A       0.50      0.63      0.56        65
#             3B       0.17      0.10      0.12        10
#             3C       0.72      0.70      0.71        33
#              4       0.33      0.08      0.12        13
# NOT APPLICABLE       0.45      0.49      0.47        43
#        UNKNOWN       0.85      0.77      0.81       383
#
#       accuracy                           0.76      2168
#      macro avg       0.60      0.56      0.57      2168
#   weighted avg       0.75      0.76      0.75      2168

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../sta_new_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#                 precision    recall  f1-score   support
#
#              0       0.80      0.78      0.79       340
#              1       0.83      0.86      0.84       959
#              2       0.70      0.75      0.73       322
#              3       0.70      0.72      0.71       108
#              4       0.00      0.00      0.00        13
# NOT APPLICABLE       0.44      0.42      0.43        43
#        UNKNOWN       0.85      0.77      0.81       383
#
#       accuracy                           0.79      2168
#      macro avg       0.62      0.61      0.62      2168
#   weighted avg       0.79      0.79      0.79      2168

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../sit_group_name_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         C500       0.67      0.25      0.36         8
#         C501       0.56      0.41      0.48       104
#         C502       0.47      0.36      0.41       233
#         C503       0.45      0.36      0.40       110
#         C504       0.62      0.63      0.62       657
#         C505       0.44      0.46      0.45       146
#         C506       0.50      0.20      0.29        10
#         C508       0.51      0.65      0.57       613
#         C509       0.37      0.29      0.32       287
#
#     accuracy                           0.52      2168
#    macro avg       0.51      0.40      0.43      2168
# weighted avg       0.52      0.52      0.51      2168

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../sit_selected_group_name_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#         C500       0.40      0.16      0.23        25
#         C501       0.29      0.26      0.27       245
#         C502       0.40      0.31      0.35       589
#         C503       0.35      0.34      0.35       235
#         C504       0.48      0.55      0.51      1593
#         C505       0.32      0.29      0.31       357
#         C506       0.21      0.16      0.18        25
#         C508       0.43      0.49      0.46      1551
#         C509       0.32      0.23      0.27       706
#
#     accuracy                           0.42      5326
#    macro avg       0.36      0.31      0.33      5326
# weighted avg       0.41      0.42      0.41      5326

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../sit_site_description_new_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=labels)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#           in       0.62      0.64      0.63      1146
#          out       0.58      0.56      0.57      1022
#
#     accuracy                           0.60      2168
#    macro avg       0.60      0.60      0.60      2168
# weighted avg       0.60      0.60      0.60      2168

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# Read the data from the text file
data = pd.read_csv('../his_group_name_BigBird_mimic_3_path_3_epoch30/predict_results.txt', delimiter='\t')

# Assuming your columns are named 'prediction' and 'label'
y_true = data['label']
y_pred = data['prediction']

# Get unique labels to use as labels in confusion matrix
labels = sorted(set(y_true) | set(y_pred))

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)

# Convert confusion matrix to DataFrame for better visualization
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

# Plot confusion matrix using seaborn heatmap
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='g')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# Compute precision, recall, and F1 score for each label
report = classification_report(y_true, y_pred, target_names=[str(label) for label in labels])

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#        80103       0.00      0.00      0.00         5
#        80323       0.00      0.00      0.00         1
#        81403       0.00      0.00      0.00         2
#        82003       1.00      1.00      1.00         1
#        82012       0.47      0.45      0.46        20
#        82013       0.00      0.00      0.00         1
#        82113       0.62      0.83      0.71        12
#        82302       0.38      0.40      0.39        25
#        82553       0.00      0.00      0.00         2
#        84012       0.00      0.00      0.00         1
#        84013       0.40      0.40      0.40         5
#        84803       0.52      0.65      0.58        23
#        84903       0.00      0.00      0.00         0
#        85002       0.67      0.71      0.69       174
#        85003       0.90      0.92      0.91      1359
#        85012       0.00      0.00      0.00         5
# ...
