# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('Q_A_dataset.csv')
df
# Out:
#                                              Question  \
# 0     What is Pho, and what are its main ingredients?
# 1              Does Pho have a strong or mild flavor?
# 2                Is Pho spicy? Can I make it spicier?
# 3   Does Pho contain any allergens I should know a...
# 4   Does the restaurant offer vegetarian or vegan ...
# ..                                                ...
# 85            What is typically served with Shawarma?
# 86                   Does Shawarma contain allergens?
# 87                     What does Shawarma taste like?
# 88                               Is Shawarma healthy?
# 89                       Can I customize my Shawarma?
#
#                                                Answer Food_Name  \
# 0   Pho is a Vietnamese noodle soup made with a fl...       pho
# 1   Pho has a mild yet aromatic flavor, with hints...       pho
# 2   Pho is not spicy by default, but you can add c...       pho
# 3   Pho may contain gluten (depending on the noodl...       pho
# 4   Many restaurants offer vegetarian or vegan ver...       pho
# ..                                                ...       ...
# 85  Shawarma is often served with pickles, fries, ...  shawarma
# 86  It may contain gluten (in the flatbread) and d...  shawarma
# 87  Shawarma has a savory and flavorful taste, wit...  shawarma
# 88  It can be healthy depending on the preparation...  shawarma
# 89  Yes, most restaurants allow you to customize S...  shawarma
#
#    question_category
# 0        Ingredients
# 1     Flavor Profile
# 2          Spiciness
# 3          Allergens
# 4    Dietary Options
# ..               ...
# 85           General
# 86         Allergens
# 87           General
# 88           General
# 89           General
#
# [90 rows x 4 columns]

# %%
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42)  # 80% train, 20% test
train_data.to_csv("train_data.csv", index=False)
test_data.to_csv("test_data.csv", index=False)

# %%
train_data
# Out:
#                                              Question  \
# 49                         What does Naan taste like?
# 62                                  What is a samosa?
# 73                          How is Shashlyk prepared?
# 69              What is the best way to eat a samosa?
# 76                                 Is Shashlyk spicy?
# ..                                                ...
# 20                    What does Banh Cuon taste like?
# 60                 What is usually served with Pilaf?
# 71      How many calories does a typical samosa have?
# 14  Is Banh Chung vegetarian, or can it be made th...
# 51                   Does Naan contain any allergens?
#
#                                                Answer   Food_Name  \
# 49  Naan is soft, fluffy, and slightly chewy with ...        naan
# 62  A samosa is a fried or baked pastry with a sav...      samosa
# 73  Shashlyk is made by marinating meat (like lamb...    shashlyk
# 69  The best way to eat a samosa is hot, paired wi...      samosa
# 76  Shashlyk is typically not very spicy, but it c...    shashlyk
# ..                                                ...         ...
# 20  Banh Cuon has a delicate, slightly chewy textu...   banh cuon
# 60  Pilaf is often served with yogurt-based sauces...       pilaf
# 71  A typical samosa has around 200 calories, depe...      samosa
# 14  Traditional Banh Chung is not vegetarian, but ...  banh chung
# 51  Yes, Naan usually contains gluten and may also...        naan
#
#    question_category
# 49           General
# 62           General
# 73           General
# 69           General
# 76         Spiciness
# ..               ...
# 20           General
# 60           General
# 71           General
# 14   Dietary Options
# 51         Allergens
#
# [72 rows x 4 columns]

# %%
test_data
# Out:
#                                              Question  \
# 40                    What does Chao Long taste like?
# 22        What are the main ingredients in Banh Cuon?
# 55                           Can Pilaf be vegetarian?
# 70           Are there any dipping sauces for samosa?
# 0     What is Pho, and what are its main ingredients?
# 26                     What does Banh Cuon come with?
# 39                                Is Chao Long spicy?
# 65                              Is samosa vegetarian?
# 10  What is Banh Chung, and what are its main ingr...
# 44                       Can Chao Long be customized?
# 81             What ingredients are used in Shawarma?
# 35    How many calories are in a serving of Banh Pia?
# 56           Does Pilaf contain any common allergens?
# 86                   Does Shawarma contain allergens?
# 12                  Is Banh Chung served hot or cold?
# 4   Does the restaurant offer vegetarian or vegan ...
# 18         How long does Banh Chung take to prepare ?
# 28                     What does Banh Pia taste like?
#
#                                                Answer   Food_Name  \
# 40  It has a rich, savory taste with a creamy text...   chao long
# 22  The main ingredients are rice flour, water, mi...   banh cuon
# 55  Yes, Pilaf can be made vegetarian by excluding...       pilaf
# 70  Yes, common dipping sauces include mint chutne...      samosa
# 0   Pho is a Vietnamese noodle soup made with a fl...         pho
# 26  It is often served with fresh herbs, slices of...   banh cuon
# 39  Chao Long is not inherently spicy but can be m...   chao long
# 65  Yes, samosas can be vegetarian if the filling ...      samosa
# 10  Banh Chung is a traditional Vietnamese sticky ...  banh chung
# 44  Yes, you can often request specific ingredient...   chao long
# 81  The main ingredients are marinated meat (chick...    shawarma
# 35  A serving of Banh Pia contains approximately 4...    banh pia
# 56  Pilaf may contain nuts or dairy depending on t...       pilaf
# 86  It may contain gluten (in the flatbread) and d...    shawarma
# 12  It is typically served warm but can also be ea...  banh chung
# 4   Many restaurants offer vegetarian or vegan ver...         pho
# 18  Banh Chung takes several hours to prepare, inc...  banh chung
# 28  Banh Pia has a unique combination of flavors: ...    banh pia
#
#    question_category
# 40           General
# 22       Ingredients
# 55   Dietary Options
# 70           General
# 0        Ingredients
# 26           General
# 39         Spiciness
# 65   Dietary Options
# 10       Ingredients
# 44           General
# 81       Ingredients
# 35           General
# 56         Allergens
# 86         Allergens
# 12           General
# 4    Dietary Options
# 18           General
# 28           General
